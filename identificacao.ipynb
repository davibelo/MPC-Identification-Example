# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read the CSV file
df = pd.read_csv('testeIdentificacao.csv', delimiter=";", index_col=0)
df.head()
# Out:
#               TC01.SP C  FC03.SP kg/hr  \
# Time Minutes
# 0                   166          10648
# 1                   166          10648
# 2                   166          10648
# 3                   166          10648
# 4                   166          10648
#
#               STREAMS("GLPHD-PR").Zn("ETHANE") kmol/kmol  \
# Time Minutes
# 0                                               0.013969
# 1                                               0.013969
# 2                                               0.013969
# 3                                               0.013969
# 4                                               0.013969
#
#               STREAMS("GLPHD-PR").Zn("PENTANE") kmol/kmol
# Time Minutes
# 0                                                 0.01527
# 1                                                 0.01527
# 2                                                 0.01527
# 3                                                 0.01527
# 4                                                 0.01527
